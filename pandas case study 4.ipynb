# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ai=pd.read_csv(r"C:\Users\DELL\Desktop\pythonn\My Notes\Dataset\adult.csv")

# %%
ad=pd.read_csv(r"C:\Users\DELL\Desktop\pythonn\My Notes\Dataset\adult.csv")

# %%
# 1.Display Top 10 Rows of The Dataset
ai.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
# 2. Check Last 10 Rows of The Dataset
ai.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %%
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)
print("number of rows",ai.shape[0])
print("number of columns",ai.shape[1])
print("number of row & column",ai.shape)
# Out:
# number of rows 48842
# number of columns 15
# number of row & column (48842, 15)

# %%
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
ai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
# 5. Fetch Random Sample From the Dataset (50%)
ai.sample(frac=0.50)
ai.sample(frac=0.50,random_state=111)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 31652   54         Local-gov  172991       HS-grad                9
# 20931   31           Private   73514       HS-grad                9
# 38653   31           Private  416415       HS-grad                9
# 32939   22           Private  203182     Bachelors               13
# 17673   59           Private  226922       HS-grad                9
# ...    ...               ...     ...           ...              ...
# 47522   60  Self-emp-not-inc   33717          11th                7
# 38727   45           Private   88061          11th                7
# 26925   43           Private  174325       7th-8th                4
# 19894   24         Local-gov  117109     Bachelors               13
# 43332   20                 ?  183083  Some-college               10
#
#               marital-status         occupation   relationship  \
# 31652     Married-civ-spouse   Transport-moving        Husband
# ...

# %%
# 6.Check Null Values In The Dataset
ai.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sns.heatmap(ai.isnull())
# Out:
# <Axes: >

# %%
ad.isin(["?"]).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
ad["workclass"].replace("?",np.NaN,inplace=True)
ad["occupation"].replace("?",np.NaN,inplace=True)
ad["native-country"].replace("?",np.NaN,inplace=True)

# %%
ad
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
# 7.Perform Data Cleaning [ Replace '?' with NaN ]
ai.replace("?",np.NaN,inplace=True)
ai
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# gender            0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
ai.isnull().sum() # column wise
# ai.isnull().sum(axis=1) # row wise
ad.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
# 8. Drop all The Missing Values
ai.isnull().sum()*100/len(ai)
ad.isnull().sum()*100/len(ai)
# Out:
# age                0.000000
# workclass          6.189465
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         6.211578
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.895095
# income             0.000000
# dtype: float64

# %%
# ai.dropna(how="any",inplace=True)
# print(ai.shape)
# ai
ad.dropna(how="any",inplace=True)
ad
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
# 9. Check For Duplicate Data and Drop Them
ai.duplicated().any()
ad.duplicated().any()
# Out:
# True

# %%
# print(ai.drop_duplicates().shape)
# ai.drop_duplicates()
print(ad.drop_duplicates().shape)
ad.drop_duplicates()
# Out:
# (45175, 15)
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
#10 :get overall data statistics about dataframe

ad.describe(include="all")
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   45222.000000     45222  4.522200e+04     45222     45222.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33307           NaN     14783              NaN
# mean       38.547941       NaN  1.897347e+05       NaN        10.118460
# std        13.217870       NaN  1.056392e+05       NaN         2.552881
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173882e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783160e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379260e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status    occupation relationship   race gender  \
# ...

# %%
# 11. Drop The Columns education-num, capital-gain, and capital-loss
ad.drop(labels=["educational-num", "capital-gain","capital-loss"],axis=1,inplace=True)

# %%
ad
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %% [markdown]
# # univariate analysis

# %%
# 12. What Is The Distribution of Age Column?
# distribution - comparing same column value with same column other values
ad["age"].describe()
# Out:
# count    45222.000000
# mean        38.547941
# std         13.217870
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
ai["age"].hist()
plt.show()

# %%
# 13. Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method
sum((ai["age"]>=17) & (ai["age"]<=48))
# Out:
# 34902

# %%
ai["age"].between(17,48).sum()
# Out:
# 34902

# %%
# 14. What is The Distribution of Workclass Column?
print(ai["workclass"].describe())
plt.figure(figsize=(10,10))
ai["workclass"].hist()
plt.show()
# Out:
# count       45222
# unique          7
# top       Private
# freq        33307
# Name: workclass, dtype: object

# %%
# 15. How Many Persons Having Bachelors and Masters Degree?
ai.columns
ai[(ai["education"]=="Bachelors") | (ai["education"]=="Masters")].shape[0]
len((ai["education"]=="Bachelors") | (ai["education"]=="Masters"))
# Out:
# 45222

# %%
len(ad["education"].isin(["Bachelors","Masters"]))
# Out:
# 45222

# %%
# 16. Bivariate Analsis - used to find relation ship between two variables or 2 columns
print(ad.columns)
sns.boxenplot(x="income",y="age",data=ai)
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='income', ylabel='age'>

# %%
# 17. Replace Salary Values With 0 and 1
print(ad.columns)
ai[ai["income"]=="<=50K".replace("<=50K","0")]
print(ai["income"].unique())
print(ai["income"].value_counts())
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')
# ['<=50K' '>50K']
# income
# <=50K    34014
# >50K     11208
# Name: count, dtype: int64

# %%
ai.replace(to_replace=["<=50K", ">50K"],value=[0,1],inplace=True)

# %%
def salary(sal):
    if sal == "<=50K":
        return 0
    else:
        return 1
ai["encoded salary"]=ai["income"].apply(salary)
ai
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %%
ai
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %%
# 18. Which Workclass Getting The Highest Salary?
ai.groupby("workclass")["income"].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.554070
# Federal-gov         0.390469
# Local-gov           0.295161
# Self-emp-not-inc    0.278978
# State-gov           0.267215
# Private             0.217702
# Without-pay         0.095238
# Name: income, dtype: float64

# %%
# 19.How Has Better Chance To Get Salary greater than 50K Male or Female?
ai.groupby("gender")["income"].sum()
ai.groupby("gender")["income"].mean().sort_values(ascending=False)
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'new salary', 'encoded salary'],
#       dtype='object')
# gender
# Male      0.312477
# Female    0.113576
# Name: income, dtype: float64

# %%
# 20. Covert workclass Columns Datatype To Category Datatype
ai["workclass"]=ai["workclass"].astype("category")

# %%
print(ai.columns)
ai.info()
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'new salary', 'encoded salary'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 45222 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45222 non-null  int64
#  1   workclass       45222 non-null  category
#  2   fnlwgt          45222 non-null  int64
#  3   education       45222 non-null  object
#  4   marital-status  45222 non-null  object
#  5   occupation      45222 non-null  object
#  6   relationship    45222 non-null  object
#  7   race            45222 non-null  object
#  8   gender          45222 non-null  object
#  9   hours-per-week  45222 non-null  int64
#  10  native-country  45222 non-null  object
#  11  income          45222 non-null  int64
# ...

# %% [markdown]
# # Read Table From The Web (URL)

# %%
banklist=pd.read_html("https://en.wikipedia.org/wiki/List_of_banks_in_India")

# %%
banklist[0]
# Out:
#               Anchor bank  Established             Headquarters  \
# 0          Bank of Baroda         1908        Vadodara, Gujarat
# 1           Bank of India         1906      Mumbai, Maharashtra
# 2     Bank of Maharashtra         1935        Pune, Maharashtra
# 3             Canara Bank         1906     Bengaluru, Karnataka
# 4   Central Bank of India         1911      Mumbai, Maharashtra
# 5             Indian Bank         1907      Chennai, Tamil Nadu
# 6    Indian Overseas Bank         1937      Chennai, Tamil Nadu
# 7    Punjab and Sind Bank         1908  New Delhi, NCT of Delhi
# 8    Punjab National Bank         1894     Dwarka, NCT of Delhi
# 9     State Bank of India         1955      Mumbai, Maharashtra
# 10               UCO Bank         1943     Kolkata, West Bengal
# 11    Union Bank of India         1919      Mumbai, Maharashtra
#
#    Government shareholding  Branches                          Total assets  \
# ...

# %%
banklist[1]
# Out:
#                    Bank name  Established                 Headquarters  \
# 0                  Axis Bank         1993          Mumbai, Maharashtra
# 1               Bandhan Bank         2015         Kolkata, West Bengal
# 2                   CSB Bank         1920             Thrissur, Kerala
# 3            City Union Bank         1904       Kumbakonam, Tamil Nadu
# 4                   DCB Bank         1930          Mumbai, Maharashtra
# 5             Dhanlaxmi Bank         1927             Thrissur, Kerala
# 6               Federal Bank         1931                Kochi, Kerala
# 7                  HDFC Bank         1994          Mumbai, Maharashtra
# 8                 ICICI Bank         1994          Mumbai, Maharashtra
# 9                  IDBI Bank         1964          Mumbai, Maharashtra
# 10           IDFC First Bank         2015          Mumbai, Maharashtra
# 11             IndusInd Bank         1994          Mumbai, Maharashtra
# ...

# %%
banklist[3]
# Out:
#                   Bank name  Established          Headquarters      Branches  \
# 0      Airtel Payments Bank         2017      New Delhi, Delhi           NaN
# 1  India Post Payments Bank         2018      New Delhi, Delhi  650 Branches
# 2       Paytm Payments Bank         2017  Noida, Uttar Pradesh           NaN
# 3         Jio Payments Bank         2018   Mumbai, Maharashtra           NaN
# 4        Fino Payments Bank         2017   Mumbai, Maharashtra  410 Branches
# 5        NSDL Payments Bank         2018   Mumbai, Maharashtra           NaN
#
#                         Revenues      Refs
# 0     ₹627 crore (US$75 million)  [72][73]
# 1     ₹55 crore (US$6.6 million)      [74]
# 2  ₹2,109 crore (US$250 million)  [75][76]
# 3     ₹13 crore (US$1.6 million)      [77]
# 4     ₹791 crore (US$95 million)  [78][79]
# 5     ₹62 crore (US$7.4 million)      [80]

# %%
len(banklist)
# Out:
# 18

# %%
banklist[10]
# Out:
#                0                                                  1
# 0         Andhra  Andhra Pradesh Grameena Vikas Bank Andhra Prag...
# 1         Kerala  Kerala Gramin Bank North Malabar Gramin Bank S...
# 2  Uttar Pradesh  Allahabad UP Gramin Bank Gramin Bank of Aryava...

# %%
banklist[11]
# Out:
#             0                                                  1
# 0      Merged  PSB New Bank of India Dena Bank Vijaya Bank Al...
# 1         PSB  New Bank of India Dena Bank Vijaya Bank Allaha...
# 2         SBI  Bank of Bombay Bank of Calcutta Bank of Madras...
# 3     Rescued  Global Trust Bank (OBC) Lakshmi Vilas Bank (DB...
# 4    Acquired  Bank of Madura Bank of Rajasthan Bengal Centra...
# 5         PSB                  Bharat Overseas Bank Pandyan Bank
# 6    Wound up  Bank of Chettinad Dass Bank Industrial Investm...
# 7      Failed  Alliance Bank of Simla Arbuthnot & Co Commerci...
# 8  Liquidated  Bengal Bank (1784) Bank of Bombay (1720) Bank ...

# %%
banklist[17]
# Out:
#              0                          1
# 0       Boards           BIFR IBBI CERSAI
# 1  Legislation            IBC SARFESI Act
# 2    Companies  ARCIL Edelweiss ARC IAMCL
