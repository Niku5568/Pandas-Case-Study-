# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
ud=pd.read_csv(r"C:\Users\DELL\Desktop\pythonn\My Notes\Dataset\Udemy_Courses.csv",parse_dates=["published_timestamp"])
ud.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration       published_timestamp              subject
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments
# 1           1 hour 2017-04-12 19:06:34+00:00  Musical Instruments

# %%
ud.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
# 1. Display Top 10 Rows of The Dataset
ud.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration       published_timestamp              subject
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments
# 1           1 hour 2017-04-12 19:06:34+00:00  Musical Instruments

# %%
# 2. Check Last 5 Rows of The Dataset
ud.tail(2)
# Out:
#       course_id                                       course_title  is_paid  \
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
#      price  num_subscribers  num_reviews  num_lectures       level  \
# 3680  Free              229            0            33  All Levels
# 3681    50               12            1            15  All Levels
#
#      content_duration       published_timestamp           subject
# 3680          2 hours 2017-05-26 16:45:55+00:00  Business Finance
# 3681        1.5 hours 2016-09-26 22:19:48+00:00    Graphic Design

# %%
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)
print("number of rows",ud.shape[0])
print("number of columns",ud.shape[1])
# Out:
# number of rows 3682
# number of columns 11

# %%
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
ud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   datetime64[ns, UTC]
#  10  subject              3682 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), int64(4), object(5)
# memory usage: 291.4+ KB

# %%
# 5. Check Null Values In The Dataset
ud.isnull().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.heatmap(ud.isnull())
# Out:
# <Axes: >

# %%
# 6. Check For Duplicate Data and Drop Them
ud.duplicated().sum()
ud.drop_duplicates()
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
# 7. Find Out Number of Courses Per Subjects
ud["subject"].value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %%
sns.countplot(x=ud["subject"])
plt.xticks(rotation=40)
plt.show()

# %%
# 8. For Which Levels, Udemy Courses Providing The Courses
ud["level"].value_counts()
# Out:
# level
# All Levels            1932
# Beginner Level        1271
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
sns.countplot(x=ud["level"])
# Out:
# <Axes: xlabel='level', ylabel='count'>

# %%
# 9. Display The Count of Paid and Free Courses 
ud["is_paid"].value_counts()
# Out:
# is_paid
# True     3372
# False     310
# Name: count, dtype: int64

# %%
sns.countplot(x=ud["is_paid"])
# Out:
# <Axes: xlabel='is_paid', ylabel='count'>

# %%
ud.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
# 10. Which Course Has More Lectures (Free or Paid)?
ud["is_paid"].value_counts()
# Out:
# is_paid
# True     3372
# False     310
# Name: count, dtype: int64

# %%
ud["is_paids"]=ud["is_paid"].replace([True,False],[1,0])

# %%
ud.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration       published_timestamp              subject  is_paids
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments         1

# %%
ud["is_paids"].value_counts()
# Out:
# is_paids
# 1    3372
# 0     310
# Name: count, dtype: int64

# %%
# 11. Which Courses Have A Higher Number of Subscribers Free or Paid?
ud.groupby("is_paid")["num_subscribers"].value_counts(ascending=False)
# Out:
# is_paid  num_subscribers
# False    5301               2
#          1                  1
#          47811              1
#          83737              1
#          73110              1
#                            ..
# True     898                1
#          896                1
#          894                1
#          891                1
#          121584             1
# Name: count, Length: 2250, dtype: int64

# %%
sns.barplot(x="is_paid",y="num_subscribers",data=ud)
# Out:
# <Axes: xlabel='is_paid', ylabel='num_subscribers'>

# %%
# 12. Which Level Has The Highest Number of Subscribers?
sns.barplot(x="level",y="num_subscribers",data=ud)
# Out:
# <Axes: xlabel='level', ylabel='num_subscribers'>

# %%
# 13. Find Most Popular Course Title
ud.columns
ud[ud["num_subscribers"].max()==ud["num_subscribers"]]["course_title"].reset_index()
# Out:
#    index                          course_title
# 0   2230  Learn HTML5 Programming From Scratch

# %%
# 14. Display 10 Most Popular Courses As Per Number of Subscribers
top=ud.sort_values(by="num_subscribers",ascending=False).head(10)
top.head(1)
# Out:
#       course_id                          course_title  is_paid price  \
# 2230      41295  Learn HTML5 Programming From Scratch    False  Free
#
#       num_subscribers  num_reviews  num_lectures       level content_duration  \
# 2230           268923         8629            45  All Levels       10.5 hours
#
#            published_timestamp          subject  is_paids
# 2230 2013-02-14 07:03:41+00:00  Web Development         0

# %%
sns.barplot(x="num_subscribers",y="course_title",data=top)
plt.show()

# %%
# 15. Find The Course Which Is Having The Highest Number of Reviews.
ud[ud["num_reviews"].max()==ud["num_reviews"]]["subject"].reset_index()
# Out:
#    index          subject
# 0   3385  Web Development

# %%
sns.barplot(x="subject",y="num_reviews",data=ud)
plt.xticks(rotation=9)
plt.show()

# %%
# 16. Does Price Affect the Number of Reviews?
ud.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject', 'is_paids'],
#       dtype='object')

# %%
plt.figure(figsize=(12,3))
sns.scatterplot(x="price",y="num_reviews",data=ud)
plt.xticks(rotation=90)
plt.show()

# %%
# 17. Find Total Number of Courses Related To Python
len(ud[ud["course_title"].str.contains("Python",case=False) ])
# Out:
# 29

# %%
# 18. Display 10 Most Popular Python Courses As Per Number of Subscribers
py=ud[ud["course_title"].str.contains("Python",case=False)].sort_values(by="num_subscribers",ascending=False).head(10)
py
# Out:
#       course_id                                       course_title  is_paid  \
# 3573      16646                        Web Programming with Python     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2955     822444  Python and Django Full Stack Web Developer Boo...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 3272     938560  The Complete Ethical Hacking Course 2.0: Pytho...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 3460      76052  Try Django 1.9 | Build a Blog and Learn Python...     True
# 2956     477702  Python for Beginners: Python Programming Langu...     True
# 3013     970600                    REST APIs with Flask and Python     True
#
#      price  num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
sns.countplot(x="num_subscribers",data=ud)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='count'>

# %%
# 19. In Which Year The Highest Number of Courses Were Posted?
ud["Year"]=ud["published_timestamp"].dt.year

# %%
count=ud["Year"].count()
count
# Out:
# 3682

# %%
sns.countplot(x="Year",data=ud)
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
# 20. Display Category-Wise Count of Posted Subjects [Year Wise] 
ud.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration       published_timestamp              subject  is_paids  \
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments         1
#
#    Year
# 0  2014

# %%
ud.groupby("Year")["subject"].value_counts()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Musical Instruments     10
#       Graphic Design          10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         56
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          66
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       349
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       229
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64

# %%
hel
